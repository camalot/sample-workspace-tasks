# %% [markdown]
# # Sample Jupyter Notebook
#
# This is a sample notebook for the Workspace Tasks extension.

# %%
print('Hello from Jupyter!')

# %%
# Run a simple computation
result = 6 * 7
print(f'The answer is {result}')

# %%
import sys
print(f'Python version: {sys.version}')
